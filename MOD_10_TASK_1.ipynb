# %%
# manipulacja danymi
import numpy as np
import pandas as pd

# wizualizacja danych
import matplotlib.pyplot as plt
import seaborn as sns

# statystyczna analiza danych
from scipy import stats

# przygotowanie danych
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# import danych
df = pd.read_csv('titanic.csv')

# przygotowanie 'Fare' do analizy
dff = df.loc[df['Fare'].notnull(), 'Fare'].values
print(dff.shape)
# Out:
# (891,)

# %%
#histogram -> dlaczego y nie jest do 100?
plt.hist(dff, bins=20)
plt.show()

# %%
plt.hist(dff, bins=20)

mean_dff = np.round(np.mean(dff))
print(mean_dff)
plt.axvline(x = mean_dff, color='red', label = 'Średnia')

median_dff = np.median(dff)
print(median_dff)
plt.axvline(x = median_dff, color='green', label = 'Mediana')


mode_dff = stats.mode(dff)
print(mode_dff)
plt.axvline(x = mode_dff[0], color='orange', label = 'Moda')

q0 = np.quantile(dff, 0.0)
q1 = np.round(np.quantile(dff, 0.25))
q3 = np.round(np.quantile(dff, 0.75))
q4 = np.round(np.quantile(dff, 1.0))
print(f'Q0: {q0}')
print(f'Q1: {q1}')
print(f'Q2: {median_dff}')
print(f'Q3: {q3}')
print(f'Q4: {q4}')
plt.axvline(x = q0, color='black', label = 'Min')
plt.axvline(x = q1, color='black', label = 'Q1')
plt.axvline(x = q3, color='black', label = 'Q3')
plt.axvline(x = q4, color='black', label = 'Max')

range_dff = max(dff) - min(dff)
print('range:', range_dff)
iqr = q3 - q1
print('iqr:', iqr)

plt.legend(loc='upper right')
plt.show()
# Out:
# 32.0
# 14.4542
# ModeResult(mode=8.05, count=43)
# Q0: 0.0
# Q1: 8.0
# Q2: 14.4542
# Q3: 31.0
# Q4: 512.0
# range: 512.3292
# iqr: 23.0

# %%
plt.boxplot(dff)
plt.show()
